# %% [markdown]
# # Synapse Task 2

# %% [markdown]
# ![WhatsApp Image 2024-07-08 at 19.53.42_bc08ba20 (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Run the following cell to import the required libraries.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Welcome to the second task on your road to being a part of the Synapse fam. This task will be focusing on the first step of beginning any ML or Data Science project which Data Preprocessing. One may ask why do we need to clean data? Imagine you are trying to make some food,you need to clean the vegetables, cut them, dice them, season them right? Any end product needs preprocessing and that is what we will be exploring in this task.
#
# Now, use this link to download the dataset and upload it to your kaggle notebook on the input window on the right side.
# https://drive.google.com/file/d/1d4Yq5AlqFkkNAsOeI2HO9jQ41EOp4qmJ/view?usp=sharing
#
# Save it under the same name as the file name if the name doesn't match one in the code given below, change the path as '/kaggle/input/folder_name/file_name.csv'
#
# We will be using this dataset to carry out basic pandas and matplotlib commands.

# %% [markdown]
# use this image as reference
#
# ![image_2024-07-09_221803305.png](data:image/png;base64,...)

# %% [markdown]
# ### To make your dataframe run this cell

# %%
df = pd.read_csv('/kaggle/input/d/ditisolanki/ge-2024-results-csv/GE_2024_Results (1).csv')
df
# Out:
#         ID                      State               Constituency  \
# 0        1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1        2  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2        3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3        4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4        4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...    ...                        ...                        ...
# 8901  8899                West Bengal                   Uluberia
# 8902  8900                West Bengal                   Uluberia
# 8903  8904  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8904  8901                West Bengal                   Uluberia
# 8905  8902                West Bengal                   Uluberia
#
#                Candidate                                        Party  \
# 0        BISHNU PADA RAY                       Bharatiya Janata Party
# 1     KULDEEP RAI SHARMA                     Indian National Congress
# 2             MANOJ PAUL          Andaman Nicobar Democratic Congress
# 3              JOE BIDEN                                     Congress
# 4             D AYYAPPAN          Communist Party of India  (Marxist)
# ...                  ...                                          ...
# 8901         NIKHIL BERA  Socialist Unity Centre Of India (COMMUNIST)
# 8902   AMAL KUMAR BARMAN                                  Independent
# 8903     Hillary Clinton                                     Congress
# 8904    RAMPRASAD GHORAI                          Indian Unity Centre
# 8905                NOTA                            None of the Above
#
#      EVM Votes Postal Votes  Total Votes % of Votes Result
# 0       102182          254     102436.0      50.58    Won
# 1        77829          211      78040.0      38.54   Lost
# 2         8236           18       8254.0       4.08   Lost
# 3          NaN          NaN          NaN        NaN   Lost
# 4         6009            8       6017.0       2.97   Lost
# ...        ...          ...          ...        ...    ...
# 8901      2095           12       2107.0       0.15   Lost
# 8902      1997            3       2000.0       0.14   Lost
# 8903       NaN          NaN          NaN        NaN   Lost
# 8904      1568            4       1572.0       0.11   Lost
# 8905     11263           55      11318.0       0.81   Lost
#
# [8906 rows x 10 columns]

# %% [markdown]
# This is a tabular dataset consisting of the results of Indian General Elections 2024. As you can see when you print the dataframe you can see its size at the bottom.

# %% [markdown]
# There is another way to find out the dimensions of a dataframe. Enter the code to find that out in the following cell.

# %%
df.shape
# Out:
# (8906, 10)

# %% [markdown]
# Write the code to display the first 20 rows of the dataframe.

# %%
df.head(20)
# Out:
#     ID                      State               Constituency  \
# 0    1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1    2  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2    3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3    4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4    4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 5    5  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 6    6  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 7    7  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8    8  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 9    4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 10   9  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 11  10  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 12  11  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 13  12  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 14  13  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 15  14             Andhra Pradesh            Amalapuram (SC)
# 16   4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 17  15             Andhra Pradesh            Amalapuram (SC)
# 18  16             Andhra Pradesh            Amalapuram (SC)
# 19  17             Andhra Pradesh            Amalapuram (SC)
#
#                  Candidate                                        Party  \
# 0          BISHNU PADA RAY                       Bharatiya Janata Party
# 1       KULDEEP RAI SHARMA                     Indian National Congress
# 2               MANOJ PAUL          Andaman Nicobar Democratic Congress
# 3                JOE BIDEN                                     Congress
# 4               D AYYAPPAN          Communist Party of India  (Marxist)
# 5          V.K. ABDUL AZIZ                                  Independent
# 6           K J B SELVARAJ     All India Anna Dravida Munnetra Kazhagam
# 7     DR ARUN KUMAR MALLIK                          Bahujan Samaj Party
# 8        RINKU MALA MONDAL                                  Independent
# 9           JUSTIN TRUDEAU                                     Congress
# 10       K VENKAT RAM BABU                                  Independent
# 11             USHA KUMARI                                  Independent
# 12          SALAMAT MONDAL  Socialist Unity Centre Of India (COMMUNIST)
# 13   ANAND RAMNATH ARLEKAR                                  Independent
# 14                    NOTA                            None of the Above
# 15   G M HARISH (BALAYOGI)                                 Telugu Desam
# 16            DONALD TRUMP                                     Congress
# 17  RAPAKA VARAPRASADA RAO        Yuvajana Sramika Rythu Congress Party
# 18           GOUTHAM JANGA                     Indian National Congress
# 19          DORABABU YALLA                          Bahujan Samaj Party
#
#    EVM Votes Postal Votes  Total Votes % of Votes Result
# 0     102182          254     102436.0      50.58    Won
# 1      77829          211      78040.0      38.54   Lost
# 2       8236           18       8254.0       4.08   Lost
# 3        NaN          NaN          NaN        NaN   Lost
# 4       6009            8       6017.0       2.97   Lost
# 5       2195            8       2203.0       1.09   Lost
# 6        911            3        914.0       0.45   Lost
# 7        714            5        719.0       0.36   Lost
# 8        539            3        542.0       0.27   Lost
# 9        NaN          NaN          NaN        NaN   Lost
# 10       506            1        507.0       0.25   Lost
# 11       378            2        380.0       0.19   Lost
# 12       349            2        351.0       0.17   Lost
# 13       342            -        342.0       0.17   Lost
# 14      1802            7       1809.0       0.89   Lost
# 15    786149        10832     796981.0      61.25    Won
# 16       NaN          NaN          NaN        NaN   Lost
# 17    450362         4423     454785.0      34.95   Lost
# 18     14523          559      15082.0       1.16   Lost
# 19      5202          186       5388.0       0.41   Lost

# %% [markdown]
# You can see that we already have one column for indices and we dont need an extra to create consfusion. Write a code to remove the ID column.

# %%
df.drop(['ID'],axis =1,inplace =True)

# %% [markdown]
# You can see some NaN values in the dataframe, these are something that will cause errors later and we don't want that. Write a code to remove these values from our dataframe. Additionally you'll see that the index values are not in order. Take care of that as well :)

# %%
newdf = df.dropna(how ="any")\
.reset_index(drop=True)
newdf
# Out:
#                           State               Constituency  \
# 0     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4     Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...                         ...                        ...
# 8897                West Bengal                   Uluberia
# 8898                West Bengal                   Uluberia
# 8899                West Bengal                   Uluberia
# 8900                West Bengal                   Uluberia
# 8901                West Bengal                   Uluberia
#
#                Candidate                                        Party  \
# 0        BISHNU PADA RAY                       Bharatiya Janata Party
# 1     KULDEEP RAI SHARMA                     Indian National Congress
# 2             MANOJ PAUL          Andaman Nicobar Democratic Congress
# 3             D AYYAPPAN          Communist Party of India  (Marxist)
# 4        V.K. ABDUL AZIZ                                  Independent
# ...                  ...                                          ...
# 8897     SK. SAPIYAR ALI                                  Independent
# 8898         NIKHIL BERA  Socialist Unity Centre Of India (COMMUNIST)
# 8899   AMAL KUMAR BARMAN                                  Independent
# 8900    RAMPRASAD GHORAI                          Indian Unity Centre
# 8901                NOTA                            None of the Above
#
#      EVM Votes Postal Votes  Total Votes % of Votes Result
# 0       102182          254     102436.0      50.58    Won
# 1        77829          211      78040.0      38.54   Lost
# 2         8236           18       8254.0       4.08   Lost
# 3         6009            8       6017.0       2.97   Lost
# 4         2195            8       2203.0       1.09   Lost
# ...        ...          ...          ...        ...    ...
# 8897      2924            -       2924.0       0.21   Lost
# 8898      2095           12       2107.0       0.15   Lost
# 8899      1997            3       2000.0       0.14   Lost
# 8900      1568            4       1572.0       0.11   Lost
# 8901     11263           55      11318.0       0.81   Lost
#
# [8902 rows x 9 columns]

# %% [markdown]
# If all is correct your dataframe should have 8902 rows and 9 columns.

# %% [markdown]
# ### The previous commands were just to make sure we have a workable dataframe now, we'll do some manipulations on the data.

# %% [markdown]
# Find out the top 5 most voted candidates in Telangana

# %%
newdf.query('State=="Telangana"')
# Out:
#           State Constituency              Candidate  \
# 6800  Telangana     Adilabad           GODAM NAGESH
# 6801  Telangana     Adilabad          ATHRAM SUGUNA
# 6802  Telangana     Adilabad           ATHRAM SAKKU
# 6803  Telangana     Adilabad  MALOTHU SYAMLAL NAYAK
# 6804  Telangana     Adilabad       MESRAM JANGUBAPU
# ...         ...          ...                    ...
# 7337  Telangana    Zahirabad            MOHD SADDAM
# 7338  Telangana    Zahirabad     MALEPU MOHAN REDDY
# 7339  Telangana    Zahirabad           ASHOK TALARI
# 7340  Telangana    Zahirabad   ROMALA BABU DURGAIAH
# 7341  Telangana    Zahirabad                   NOTA
#
#                                      Party EVM Votes Postal Votes  \
# 6800                Bharatiya Janata Party    558936         9232
# 6801              Indian National Congress    472333         5183
# 6802                Bharat Rashtra Samithi    136463          837
# 6803  Alliance of Democratic Reforms Party      7489           10
# 6804                   Bahujan Samaj Party      6689           55
# ...                                    ...       ...          ...
# 7337                           Independent      1567            1
# 7338                Pyramid Party of India      1095            7
# 7339                           Independent       831            6
# 7340              India Praja Bandhu Party       601            2
# 7341                     None of the Above      2933           44
#
#       Total Votes % of Votes Result
# 6800     568168.0      45.98    Won
# 6801     477516.0      38.65   Lost
# 6802     137300.0      11.11   Lost
# 6803       7499.0       0.61   Lost
# 6804       6744.0       0.55   Lost
# ...           ...        ...    ...
# 7337       1568.0       0.13   Lost
# 7338       1102.0       0.09   Lost
# 7339        837.0       0.07   Lost
# 7340        603.0       0.05   Lost
# 7341       2977.0       0.24   Lost
#
# [542 rows x 9 columns]

# %%
df_state = newdf[['State', 'Candidate', 'Total Votes']]
df_state
# Out:
#                           State           Candidate  Total Votes
# 0     Andaman & Nicobar Islands     BISHNU PADA RAY     102436.0
# 1     Andaman & Nicobar Islands  KULDEEP RAI SHARMA      78040.0
# 2     Andaman & Nicobar Islands          MANOJ PAUL       8254.0
# 3     Andaman & Nicobar Islands          D AYYAPPAN       6017.0
# 4     Andaman & Nicobar Islands     V.K. ABDUL AZIZ       2203.0
# ...                         ...                 ...          ...
# 8897                West Bengal     SK. SAPIYAR ALI       2924.0
# 8898                West Bengal         NIKHIL BERA       2107.0
# 8899                West Bengal   AMAL KUMAR BARMAN       2000.0
# 8900                West Bengal    RAMPRASAD GHORAI       1572.0
# 8901                West Bengal                NOTA      11318.0
#
# [8902 rows x 3 columns]

# %%
df_state.iloc[6803:7344, :]\
.sort_values('Total Votes',ascending=False)
# Out:
#           State                        Candidate  Total Votes
# 7049  Telangana                  EATALA RAJENDER     991042.0
# 6853  Telangana          KONDA VISHWESHWAR REDDY     809882.0
# 7137  Telangana                KUNDURU RAGHUVEER     784337.0
# 7342    Tripura             KRITI DEVI DEBBARMAN     777447.0
# 6957  Telangana       RAMASAHAYAM RAGHURAM REDDY     766929.0
# ...         ...                              ...          ...
# 7276  Telangana                    KONDOJU MOHAN        114.0
# 6924  Telangana                         ANIL SEN        111.0
# 7277  Telangana               MD KHALEEL UZ ZAMA        111.0
# 6925  Telangana  CHAITANYA KUMAR REDDY PELLAKURU        110.0
# 6926  Telangana                  SILIVERU NARESH        103.0
#
# [541 rows x 3 columns]

# %% [markdown]
# Find out the total number of votes received by each state

# %%
agg_function = {'Total Votes':'sum',}
df_news= df_state.groupby(df_state['State']).aggregate(agg_function).reset_index()
df_news
# Out:
#                                    State  Total Votes
# 0              Andaman & Nicobar Islands     202514.0
# 1                         Andhra Pradesh   33729342.0
# 2                      Arunachal Pradesh     723247.0
# 3                                  Assam   20059870.0
# 4                                  Bihar   43448949.0
# 5                             Chandigarh     449275.0
# 6                           Chhattisgarh   15061348.0
# 7   Dadra & Nagar Haveli and Daman & Diu     297998.0
# 8                                    Goa     906538.0
# 9                                Gujarat   29115599.0
# 10                               Haryana   13055572.0
# 11                      Himachal Pradesh    4069906.0
# 12                     Jammu and Kashmir    5151193.0
# 13                             Jharkhand   17241982.0
# 14                             Karnataka   38793617.0
# 15                                Kerala   19980436.0
# 16                                Ladakh     135524.0
# 17                           Lakshadweep      49200.0
# 18                        Madhya Pradesh   37940251.0
# 19                           Maharashtra   57179133.0
# 20                               Manipur    1593632.0
# 21                             Meghalaya    1711967.0
# 22                               Mizoram     491336.0
# 23                          NCT OF Delhi    8938049.0
# 24                              Nagaland     760796.0
# 25                                Odisha   25129026.0
# 26                            Puducherry     807940.0
# 27                                Punjab   13530923.0
# 28                             Rajasthan   33164877.0
# 29                                Sikkim     384893.0
# 30                            Tamil Nadu   43674048.0
# 31                             Telangana   22008373.0
# 32                               Tripura    2344154.0
# 33                         Uttar Pradesh   87911642.0
# 34                           Uttarakhand    4836608.0
# 35                           West Bengal   60483687.0

# %% [markdown]
# Show these values as a percentage of the total number of votes received in the election.

# %%
df_news['Total percentage']= (df_news['Total Votes']/df_news['Total Votes'].sum())*100
df_news
# Out:
#                                    State  Total Votes  Total percentage
# 0              Andaman & Nicobar Islands     202514.0          0.031380
# 1                         Andhra Pradesh   33729342.0          5.226410
# 2                      Arunachal Pradesh     723247.0          0.112068
# 3                                  Assam   20059870.0          3.108306
# 4                                  Bihar   43448949.0          6.732478
# 5                             Chandigarh     449275.0          0.069616
# 6                           Chhattisgarh   15061348.0          2.333778
# 7   Dadra & Nagar Haveli and Daman & Diu     297998.0          0.046175
# 8                                    Goa     906538.0          0.140469
# 9                                Gujarat   29115599.0          4.511504
# 10                               Haryana   13055572.0          2.022980
# 11                      Himachal Pradesh    4069906.0          0.630638
# 12                     Jammu and Kashmir    5151193.0          0.798185
# 13                             Jharkhand   17241982.0          2.671670
# 14                             Karnataka   38793617.0          6.011127
# 15                                Kerala   19980436.0          3.095997
# 16                                Ladakh     135524.0          0.021000
# 17                           Lakshadweep      49200.0          0.007624
# 18                        Madhya Pradesh   37940251.0          5.878897
# 19                           Maharashtra   57179133.0          8.859989
# 20                               Manipur    1593632.0          0.246936
# 21                             Meghalaya    1711967.0          0.265272
# 22                               Mizoram     491336.0          0.076133
# 23                          NCT OF Delhi    8938049.0          1.384964
# 24                              Nagaland     760796.0          0.117886
# 25                                Odisha   25129026.0          3.893779
# 26                            Puducherry     807940.0          0.125191
# 27                                Punjab   13530923.0          2.096636
# 28                             Rajasthan   33164877.0          5.138946
# 29                                Sikkim     384893.0          0.059640
# 30                            Tamil Nadu   43674048.0          6.767357
# 31                             Telangana   22008373.0          3.410229
# 32                               Tripura    2344154.0          0.363230
# 33                         Uttar Pradesh   87911642.0         13.622036
# 34                           Uttarakhand    4836608.0          0.749439
# 35                           West Bengal   60483687.0          9.372035

# %% [markdown]
# Now, display the top 5 parties and find out the number of votes received by them

# %%
df_party =newdf[['Party','Candidate', 'Total Votes']]
df_party
# Out:
#                                             Party           Candidate  \
# 0                          Bharatiya Janata Party     BISHNU PADA RAY
# 1                        Indian National Congress  KULDEEP RAI SHARMA
# 2             Andaman Nicobar Democratic Congress          MANOJ PAUL
# 3             Communist Party of India  (Marxist)          D AYYAPPAN
# 4                                     Independent     V.K. ABDUL AZIZ
# ...                                           ...                 ...
# 8897                                  Independent     SK. SAPIYAR ALI
# 8898  Socialist Unity Centre Of India (COMMUNIST)         NIKHIL BERA
# 8899                                  Independent   AMAL KUMAR BARMAN
# 8900                          Indian Unity Centre    RAMPRASAD GHORAI
# 8901                            None of the Above                NOTA
#
#       Total Votes
# 0        102436.0
# 1         78040.0
# 2          8254.0
# 3          6017.0
# 4          2203.0
# ...           ...
# 8897       2924.0
# 8898       2107.0
# 8899       2000.0
# 8900       1572.0
# 8901      11318.0
#
# [8902 rows x 3 columns]

# %%
agg_function = {'Total Votes':'sum',}
df_newp= df_party.groupby(df_party['Party']).aggregate(agg_function)
df_newp.sort_values('Total Votes',ascending=False).head(5).reset_index()
# Out:
#                           Party  Total Votes
# 0        Bharatiya Janata Party  235973935.0
# 1      Indian National Congress  136759064.0
# 2               Samajwadi Party   29549381.0
# 3  All India Trinamool Congress   28213393.0
# 4                   Independent   17844442.0

# %% [markdown]
# From the candidates who lost, list 10 candidates who got the highest percent votes.

# %%
df_lost= newdf[['Candidate', 'Total Votes', 'Result']]
df_lost
# Out:
#                Candidate  Total Votes Result
# 0        BISHNU PADA RAY     102436.0    Won
# 1     KULDEEP RAI SHARMA      78040.0   Lost
# 2             MANOJ PAUL       8254.0   Lost
# 3             D AYYAPPAN       6017.0   Lost
# 4        V.K. ABDUL AZIZ       2203.0   Lost
# ...                  ...          ...    ...
# 8897     SK. SAPIYAR ALI       2924.0   Lost
# 8898         NIKHIL BERA       2107.0   Lost
# 8899   AMAL KUMAR BARMAN       2000.0   Lost
# 8900    RAMPRASAD GHORAI       1572.0   Lost
# 8901                NOTA      11318.0   Lost
#
# [8902 rows x 3 columns]

# %%
agg_function = {'Total Votes':'sum',}
df_newl=df_lost.query('Result=="Lost" and Candidate!="NOTA"')\
.groupby(df_lost['Candidate']).aggregate(agg_function)\
.sort_values('Total Votes',ascending=False).head(10).reset_index()
df_newl
# Out:
#                                 Candidate  Total Votes
# 0                              D K SURESH     809355.0
# 1                         NISITH PRAMANIK     749125.0
# 2                              RAJ BABBAR     733257.0
# 3              PROFESSOR M.V RAJEEV GOWDA     726573.0
# 4  UTTAM BARIK SON OF LATE BIRENDRA BARIK     715431.0
# 5                          PRAHLAD GUNJAL     708522.0
# 6                          KANHAIYA KUMAR     706265.0
# 7                        ARUP KANTI DIGAR     706188.0
# 8                  DEBANGSHU BHATTACHARYA     687851.0
# 9                     PORLAL BATHA KHARTE     684845.0

# %%
df_newl['Total Percent']=(df_newl['Total Votes']/df_newl['Total Votes'].sum())*100
df_newl
# Out:
#                                 Candidate  Total Votes  Total Percent
# 0                              D K SURESH     809355.0      11.198407
# 1                         NISITH PRAMANIK     749125.0      10.365052
# 2                              RAJ BABBAR     733257.0      10.145499
# 3              PROFESSOR M.V RAJEEV GOWDA     726573.0      10.053018
# 4  UTTAM BARIK SON OF LATE BIRENDRA BARIK     715431.0       9.898855
# 5                          PRAHLAD GUNJAL     708522.0       9.803260
# 6                          KANHAIYA KUMAR     706265.0       9.772032
# 7                        ARUP KANTI DIGAR     706188.0       9.770966
# 8                  DEBANGSHU BHATTACHARYA     687851.0       9.517252
# 9                     PORLAL BATHA KHARTE     684845.0       9.475660

# %% [markdown]
# ### These techniques help to understand the data that we have but we like something a bit more visual right? That's where matplotlib comes to our aid.

# %% [markdown]
# Make a piechart to show the votes recieved by the top 5 candidates in the elections.

# %%
df_new= df_lost[['Candidate','Total Votes']]
agg_function = {'Total Votes':'sum',}
df_new=df_lost.query('Candidate!="NOTA"')\
.groupby(df_lost['Candidate']).aggregate(agg_function)\
.sort_values('Total Votes',ascending=False).head(5).reset_index()
df_new
# Out:
#                Candidate  Total Votes
# 0        RAKIBUL HUSSAIN    1471885.0
# 1           RAHUL GANDHI    1335094.0
# 2        SHANKAR LALWANI    1226751.0
# 3  SHIVRAJ SINGH CHOUHAN    1116460.0
# 4       DR C N MANJUNATH    1079002.0

# %%
candidates = df_new['Candidate'].to_numpy()
plt.pie(df_new['Total Votes'], labels=candidates, autopct="%1.1f%%")
plt.title('Top 5 Candidates')
plt.show()

# %% [markdown]
# Make a bar graph to see the postal votes received by the parties in Karnataka

# %%
df_postal = newdf[['State', 'Party', 'Postal Votes']]
df_postal
# Out:
#                           State                                        Party  \
# 0     Andaman & Nicobar Islands                       Bharatiya Janata Party
# 1     Andaman & Nicobar Islands                     Indian National Congress
# 2     Andaman & Nicobar Islands          Andaman Nicobar Democratic Congress
# 3     Andaman & Nicobar Islands          Communist Party of India  (Marxist)
# 4     Andaman & Nicobar Islands                                  Independent
# ...                         ...                                          ...
# 8897                West Bengal                                  Independent
# 8898                West Bengal  Socialist Unity Centre Of India (COMMUNIST)
# 8899                West Bengal                                  Independent
# 8900                West Bengal                          Indian Unity Centre
# 8901                West Bengal                            None of the Above
#
#      Postal Votes
# 0             254
# 1             211
# 2              18
# 3               8
# 4               8
# ...           ...
# 8897            -
# 8898           12
# 8899            3
# 8900            4
# 8901           55
#
# [8902 rows x 3 columns]

# %%
df_postal = df_postal.query('State=="Karnataka"')
agg_function = {'Postal Votes':'sum',}
df_postal=df_postal.groupby(df_postal['Party']).aggregate(agg_function).reset_index()
df_postal
# Out:
#                                           Party  \
# 0                      All India Ulama Congress
# 1                          Bahujan Bharat Party
# 2                           Bahujan Samaj Party
# 3                 Bharatheeya Jawan Kisan Party
# 4                        Bharatiya Janata Party
# 5            Bharatiya Prajagala Kalyana Paksha
# 6                     Bhartiya Jan Samrat Party
# 7                     BhartiyaBahujanKranti Dal
# 8                             Challengers Party
# 9           Communist Party of India  (Marxist)
# 10                        Country Citizen Party
# 11                            Delhi Janta Party
# 12                              Desh Prem Party
# 13                     Digvijaya Bharatha Party
# 14                  Dr. Ambedkar People's Party
# 15                      Ekam Sanatan Bharat Dal
# 16                           Gareeb Aadmi Party
# 17                                  Independent
# 18         Indian Labour Party (Ambedkar Phule)
# 19                        Indian Movement Party
# 20                     Indian National Congress
# 21                             Janahitha Paksha
# 22                        Janata Dal  (Secular)
# 23                              Kannada  Paksha
# 24               Kannada Chalavali Vatal Paksha
# 25                      Karnataka Jantha Paksha
# 26                   Karnataka Karmikara Paksha
# 27          Karnataka Praja Party (RaithaParva)
# 28                    Karnataka Rashtra Samithi
# 29                              Karunaadu Party
# 30                      Karunada Sevakara Party
# 31                    Kranti Kari Jai Hind Sena
# 32                    Naki Bharatiya Ekta Party
# 33                    National Maha Sabha Party
# 34                             Navabharath Sena
# 35                            None of the Above
# 36                       Prahar Janshakti Party
# 37                         Proutist Bloc, India
# 38                         Proutist Sarva Samaj
# 39                     Purvanchal Mahapanchayat
# 40                       Pyramid Party of India
# 41                           Raita Bharat Party
# 42                         Rani Chennamma Party
# 43                      Rashtriya Samaj Dal (R)
# 44                       Rashtriya Samaj Paksha
# 45                Republican Party of India (A)
# 46        Republican Party of India (Karnataka)
# 47           Republican Party of India Bharatha
# 48                     Samaj Vikas Kranti Party
# 49            Samajwadi Janata Party(Karnataka)
# 50                           Sarva Janata Party
# 51                  Secular Democratic Congress
# 52                      Socialist Party (India)
# 53  Socialist Unity Centre Of India (COMMUNIST)
# 54                            Tipu Sultan Party
# 55                     Uttama Prajaakeeya Party
# 56               Viduthalai Chiruthaigal Katchi
# 57                     Voters Independent Party
# 58                 Young Star Empowerment Party
#
#                                          Postal Votes
# 0                                                 106
# 1                                             5021120
# 2           26161795710138412263013171054412611473339
# 3                                                  15
# 4   3598167932443449305055582040167637261909303144...
# 5                                               41454
# 6                                                  15
# 7                                                   7
# 8                                                   1
# 9                                                  11
# 10                                               3823
# 11                                                  9
# 12                                                  3
# 13                                                  7
# 14                                                 15
# 15                                                  -
# 16                                                  3
# 17  16945132184225648-77--12374284-754463212848103...
# 18                                                553
# 19                                                 21
# 20  1899840138318969932695126411552275174516702638...
# 21                                                120
# 22                                       380322964399
# 23                                                  -
# 24                                                 10
# 25                                                511
# 26                                                  -
# 27                                                  6
# 28            513441353139331118189252483091158612433
# 29                                              61210
# 30                                               4145
# 31                                                  4
# 32                                                127
# 33                                                  6
# 34                                                346
# 35  2223551627431812204951373461112113713433233044...
# 36                                               2346
# 37                                                 32
# 38                                                 20
# 39                                                166
# 40                                                  6
# 41                                                  9
# 42                                                 -1
# 43                                               1032
# 44                                                 10
# 45                                             103718
# 46                                                286
# 47                                                  5
# 48                                                  2
# 49                                               4514
# 50                                                194
# 51                                                  3
# 52                                                389
# 53                          7756152175818719869225945
# 54                                                 49
# 55                  144111142051976415371411123033443
# 56                                                 77
# 57                                                  7
# 58                                               1-21

# %%
plt.bar(df_postal['Party'],df_postal['Postal Votes'], color='blue')
plt.xlabel("Parties in Karnataka")
plt.ylabel("Postal Votes")
plt.title('Postal votes of parties in Karnataka')
plt.show()

# %% [markdown]
# ### Congratulations on making it to the end. EDA is a very vital toolkit to tackle Machine Learning problems. Hopefully this task helped you understand concepts of data analysis and visualisation. See you at the interviews :)

# %% [markdown]
# For any doubts contact:
#
# Taran Shah: +91 9619223242
#
# Divyam Jain: +91 96193 77044
